# %%
# !pip install pymoo

# %%
import pickle as p
import numpy as np
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from scipy import stats
import os

plt.rc('legend', fontsize=13)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=11)
plt.rc('axes', labelsize=13)
plt.rcParams["font.family"] = "serif"

# %% [markdown]
# ## Summarize results

# %%
def find_the_better(x, y):
    if isinstance(x, list):
        x = np.array(x)
    if isinstance(y, list):
        y = np.array(y)
    sub_ = x - y
    x_better = np.all(sub_ <= 0)
    y_better = np.all(sub_ >= 0)
    if x_better == y_better:  # True - True
        return -1
    if y_better:  # False - True
        return 1
    return 0  # True - False

def get_front_0(F):
    l = len(F)
    r = np.zeros(l, dtype=np.int8)
    for i in range(l):
        if r[i] == 0:
            for j in range(i + 1, l):
                better_sol = find_the_better(F[i], F[j])
                if better_sol == 0:
                    r[j] += 1
                elif better_sol == 1:
                    r[i] += 1
                    break
    return r == 0

def calculate_IGD(af):
    af = np.array(af)
    af[:, 1] = (af[:, 1] - min_params) / (max_params - min_params)
    af = np.round(af, 4)
    igd_value = IGD_computing(af)
    return igd_value


def calculate_HV(af):
    hv_value = HV_computing(af)
    return np.round(hv_value / np.prod(reference_point), 6)

def evaluate(list_arch, list_hashKey):
    F = []
    for i, arch in enumerate(list_arch):
        hashKey = list_hashKey[i]
        test_error = np.round(1 - benchmark_data['108'][hashKey]['test_acc'], 4)
        efficiency_metric = np.round(benchmark_data['108'][hashKey]['n_params'], 4)
        f = [test_error, efficiency_metric]
        F.append(f)

    F = np.array(F)
    list_arch = np.array(list_arch)

    fr0 = get_front_0(F)
    AF = F[fr0]
    AF = np.unique(AF, axis=0)
    AS = list_arch[fr0]

    igd_value = calculate_IGD(AF)
    hv_value = calculate_HV(AF)
    best_test_acc = np.round((1 - np.min(AF[:, 0])) * 100, 2)
    opt_results = {
        'Approximation Set': AS,
        'Approximation Front': AF,
        'IGD': igd_value,
        'HV': hv_value,
        'Best testing accuracy': best_test_acc,
    }
    return opt_results



def summarize_results():
    list_variant = [
        'val_error',
        'synflow', 'jacov', 'snip', 'grad_norm', 'grasp', 'fisher',
        'ENAS_TFI', 'MOENAS_PSI', 'MOENAS_TF_PSI',
        'E-TF-MOENAS', 'E-TF-MOENAS-C'
    ]
    for variant in list_variant:
        print('Algorithm:', variant)
        algo_res_path = f'{RES_PATH}/NAS101_{variant}'

        if not os.path.exists(algo_res_path):
           continue
        nEvals_all = []
        rt_all = []
        EA_all = []
        IGD_all = []
        HV_all = []
        list_exp = list(os.listdir(algo_res_path))
        for rid in list_exp:
            if 'txt' in rid:
                continue
            IGD_history = []
            HV_history = []
            EA_history = []

            exp_res_path = algo_res_path + f'/{rid}'

            nEvals_runningtime_each_gen = p.load(open(exp_res_path + '/#Evals_runningtime_each_gen.p', 'rb'))
            nEvals_runningtime_each_gen = np.array(nEvals_runningtime_each_gen)

            nEvals_history = (nEvals_runningtime_each_gen[:, 0].astype(int)).tolist()
            running_time_history = (nEvals_runningtime_each_gen[:, 1].astype(int) + 1).tolist()

            E_Archive_search_each_gen = p.load(open(exp_res_path + '/E_Archive_search_each_gen.p', 'rb'))
            for EA in E_Archive_search_each_gen:
                rs_evaluation = evaluate(EA['X'], EA['hashKey'])

                ea = {
                    'X_lst': rs_evaluation['Approximation Set'],
                    'F_lst': rs_evaluation['Approximation Front'],
                }

                igd_value = rs_evaluation['IGD']
                hv_value = rs_evaluation['HV']

                EA_history.append(ea)
                IGD_history.append(igd_value)
                HV_history.append(hv_value)

            nEvals_all.append(nEvals_history)
            rt_all.append(running_time_history)
            EA_all.append(EA_history)
            IGD_all.append(IGD_history)
            HV_all.append(HV_history)

        nEvals_all = np.array(nEvals_all)
        rt_all = np.array(rt_all)
        IGD_all = np.array(IGD_all)

        nEvals_all = np.array(nEvals_all)
        rt_all = np.array(rt_all)
        IGD_all = np.array(IGD_all)
        HV_all = np.array(HV_all)

        rs_all = {
            'nEvals_all': nEvals_all,
            'running_time_all': rt_all,
            'EA_all': EA_all,
            'IGD_all': IGD_all,
            'HV_all': HV_all,
        }
        p.dump(rs_all, open(f'{RES_PATH}/raw_results_{variant}.p', 'wb'))


def processing_results():
    list_variant = [
        'val_error',
        'synflow', 'jacov', 'snip', 'grad_norm', 'grasp', 'fisher',
        'ENAS_TFI', 'MOENAS_PSI', 'MOENAS_TF_PSI',
        'E-TF-MOENAS', 'E-TF-MOENAS-C'
    ]

    for variant in list_variant:
        print('Algorithm:', variant)
        raw_res = p.load(open(f'{RES_PATH}/raw_results_{variant}.p', 'rb'))

        best_arch_found = []
        final_EA = []
        final_IGD = []
        final_HV = []
        final_running_time = []

        n_run = len(raw_res['EA_all'])
        for i in range(n_run):
            EA = raw_res['EA_all'][i][-1]
            F = EA['F_lst']
            best_arch = np.round((1 - np.min(F[:, 0])) * 100, 2)
            IGD_value = raw_res['IGD_all'][i][-1]
            HV_value = raw_res['HV_all'][i][-1]
            rt = raw_res['running_time_all'][i][-1]

            best_arch_found.append(best_arch)
            final_IGD.append(IGD_value)
            final_HV.append(HV_value)
            final_running_time.append(rt)
            final_EA.append(EA)

        rs_final = {
            'best_arch_found': best_arch_found,
            'final_EA': final_EA,
            'final_IGD': final_IGD,
            'final_HV': final_HV,
            'running_time_avg': int(np.mean(final_running_time)) + 1
        }
        p.dump(rs_final, open(f'{RES_PATH}/{variant}.p', 'wb'))

# %% [markdown]
# ## Visualize results

# %%
def visualize_mean_std(obj0_mean, obj1_mean, obj1_std, label, line):
    color = line[0]
    style = line[1]
    ax.plot(obj0_mean, obj1_mean, c=color, ls=style, label=label, linewidth=1.5)
    ax.fill_between(obj0_mean, obj1_mean - obj1_std, obj1_mean + obj1_std, alpha=0.1, fc=color)

def visualize_xaxis_nEvals():
    list_variant = [
        'val_error',
        'synflow',
        'jacov',
        'E-TF-MOENAS',
        'E-TF-MOENAS-C'
    ]

    labels = [
        'NSGAII (val-error)',
        'NSGAII (synflow)',
        'NSGAII (jacov)',
        'E-TF-MOENAS',
        'E-TF-MOENAS-C'
    ]

    colors = {
        'NSGAII (val-error)': ['blue', '-.'],
        'NSGAII (synflow)': ['tab:orange', '-.'],
        'NSGAII (jacov)': ['purple', '-.'],
        'E-TF-MOENAS': ['red', '-.'],
        'E-TF-MOENAS-C': ['brown', '-.'],
    }

    list_raw_res = [f'{RES_PATH}/raw_results_{variant}.p' for variant in list_variant]

    algo_hv_mean = []
    algo_hv_std = []

    algo_igd_mean = []
    algo_igd_std = []

    algo_nEvals = []
    for raw_res in list_raw_res:
        res = p.load(open(raw_res, 'rb'))
        IGD_all = res['IGD_all']
        HV_all = res['HV_all']
        nEvals = res['nEvals_all'][0]

        HV_mean = np.mean(HV_all, axis=0)
        HV_std = np.std(HV_all, axis=0)

        IGD_mean = np.mean(IGD_all, axis=0)
        IGD_std = np.std(IGD_all, axis=0)

        algo_hv_mean.append(HV_mean)
        algo_hv_std.append(HV_std)

        algo_igd_mean.append(IGD_mean)
        algo_igd_std.append(IGD_std)

        algo_nEvals.append(nEvals)

    ends = [20, 100, 1000, 3000]

    for i in range(len(algo_igd_mean)):
        if metric == 'IGD':
            visualize_mean_std(algo_nEvals[i], algo_igd_mean[i], algo_igd_std[i], labels[i], line=colors[labels[i]])
        else:
            visualize_mean_std(algo_nEvals[i], algo_hv_mean[i], algo_hv_std[i], labels[i], line=colors[labels[i]])

    ax.set_xscale('log')
    ax.set_xticks(ends)
    ax.get_xaxis().set_major_formatter(FormatStrFormatter('%.2d'))
    ax.set_xlabel('#Evals')
    ax.set_ylabel(metric)

    plt.grid(True, linestyle='--')
    plt.title('NASBench101', fontsize=20)

    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.1, box.width, box.height * 0.9])
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=3)
    plt.savefig(f'{RES_PATH}/nEvals_{metric}_101.jpg', bbox_inches='tight', pad_inches=0.1, dpi=300)

def visualize_xaxis_hours():
    list_variant = [
        'val_error',
        'synflow',
        'jacov',
        'E-TF-MOENAS',
        'E-TF-MOENAS-C'
    ]

    labels = [
        'NSGAII (val-error)',
        'NSGAII (synflow)',
        'NSGAII (jacov)',
        'E-TF-MOENAS',
        'E-TF-MOENAS-C'
    ]

    colors = {
        'NSGAII (val-error)': ['blue', '-.'],
        'NSGAII (synflow)': ['tab:orange', '-.'],
        'NSGAII (jacov)': ['purple', '-.'],
        'E-TF-MOENAS': ['red', '-.'],
        'E-TF-MOENAS-C': ['brown', '-.'],
    }

    list_raw_res = [f'{RES_PATH}/raw_results_{variant}.p' for variant in list_variant]

    algo_hv_mean = []
    algo_hv_std = []

    algo_igd_mean = []
    algo_igd_std = []

    algo_rt = []

    for raw_res in list_raw_res:
        res = p.load(open(raw_res, 'rb'))
        IGD_all = res['IGD_all']
        HV_all = res['HV_all']
        rt_all = res['running_time_all']

        HV_mean = np.mean(HV_all, axis=0)
        HV_std = np.std(HV_all, axis=0)

        IGD_mean = np.mean(IGD_all, axis=0)
        IGD_std = np.std(IGD_all, axis=0)
        rt_mean = np.round(np.mean(rt_all, axis=0)/3600, 4)

        algo_hv_mean.append(HV_mean)
        algo_hv_std.append(HV_std)

        algo_igd_mean.append(IGD_mean)
        algo_igd_std.append(IGD_std)

        algo_rt.append(rt_mean)

    ends = [0.01, 0.3138, 0.8986, 1.5857, 97.1555]

    for i in range(len(algo_igd_mean)):
        if metric == 'IGD':
            visualize_mean_std(algo_rt[i], algo_igd_mean[i], algo_igd_std[i], labels[i], line=colors[labels[i]])
        else:
            visualize_mean_std(algo_rt[i], algo_hv_mean[i], algo_hv_std[i], labels[i], line=colors[labels[i]])

    ax.set_xscale('log')
    ax.set_xticks(ends)
    ax.get_xaxis().set_major_formatter(FormatStrFormatter('%.2f'))
    ax.set_xlabel('GPUs Hours')
    ax.set_ylabel(metric)

    plt.xticks(rotation=90)
    plt.grid(True, linestyle='--')

    if metric == 'IGD':
        plt.legend(loc=1)
    else:
        plt.legend(loc=4)
    # box = ax.get_position()
    # ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    # plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.title('NASBench101', fontsize=20)
    plt.savefig(f'{RES_PATH}/runtime_{metric}_101.jpg', bbox_inches='tight', pad_inches=0.1, dpi=300)

# %% [markdown]
# ## T-test

# %%
alpha = 0.05


def return_IGD_HV(rs):
    return rs['final_IGD'], rs['final_HV']

def compare(x, y, name_x, name_y, metric='IGD', a=0.05):
    p_value = stats.ttest_ind(x, y)[-1]

    print(metric, name_x, name_y)
    print('p_value:', p_value)

    if np.isnan(p_value):
        p_value = 1
    if p_value <= a:
        mean_1 = np.mean(x)
        mean_2 = np.mean(y)
        std_1 = np.std(x)
        std_2 = np.std(y)
        cohen_d = (abs(mean_1 - mean_2)) / ((std_1 ** 2 + std_2 ** 2) / 2) ** (1 / 2)
        if cohen_d >= 0.8:
            effect_size = 'large'
        elif cohen_d >= 0.5:
            effect_size = 'medium'
        elif cohen_d >= 0.2:
            effect_size = 'small'
        else:
            effect_size = 'trivial'
        rs = np.mean(y) - np.mean(x)
        if metric in ['HV', 'best_arch_found']:
            rs *= -1
        if rs > 0:
            rs_compare = 'worse'
        else:
            rs_compare = 'better'
        print('Reject |', rs_compare, effect_size)
    print()

def print_mean_std(_all, round_pre=4):
    _mean = np.mean(_all, axis=0)
    _std = np.std(_all, axis=0)
    print(f'{np.round(_mean, round_pre)} ({np.round(_std, round_pre)})')

def print_running_time_avg(rs):
    try:
        print('Running Time (avg):', rs['running_time_avg'])
    except:
        pass

def print_best_arch_mean_std(rs):
    _mean = np.round(np.mean(rs['best_arch_found']), 2)
    _std = np.round(np.std(rs['best_arch_found']), 2)
    print(f'Best (mean & std): {_mean} ({_std})')

def run_t_test():
    print('Dataset:', 'CIFAR-10')

    list_variant = [
        'val_error',
        'moead-val_error',
        'synflow', 'jacov', 'snip', 'grad_norm', 'grasp', 'fisher',
        'ENAS_TFI', 'MOENAS_PSI', 'MOENAS_TF_PSI',
        'E-TF-MOENAS', 'E-TF-MOENAS-C'
    ]

    list_competitor = []
    for i, variant in enumerate(list_variant):
        if os.path.exists(RES_PATH + f'/{variant}.p'):
            print(variant)
            res = p.load(open(RES_PATH + f'/{variant}.p', 'rb'))

            igd, hv = return_IGD_HV(res)
            print('IGD: ', end='')
            print_mean_std(igd)
            print('HV: ', end='')
            print_mean_std(hv)
            print_running_time_avg(res)
            print_best_arch_mean_std(res)
            performance = {
                'variant': variant,
                'IGD': igd,
                'HV': hv,
                'best_arch_found': res['best_arch_found']
            }
            list_competitor.append(performance)
            print('-' * 100)
    print('='*20)
    print()
    n_competitor = len(list_competitor)
    # n_competitors = 2
    print(f'Alpha: {alpha/n_competitor}\n')
    for metric in ['IGD', 'HV']:
        print('Metric:', metric)
        for i in range(len(list_competitor)):
            for j in range(i + 1, len(list_competitor)):
                pair = [list_competitor[i][metric], list_competitor[j][metric],
                        list_competitor[i]['variant'], list_competitor[j]['variant'], metric, alpha/n_competitor]
                compare(*pair)
        print('='*100)
        print()

# %% [markdown]
# ## Main

# %%
RES_PATH = '/content/drive/MyDrive/Information_Sciences/nas101'  # Experiment Results Path
DATABASE_PATH = '/content/drive/MyDrive/Benchmark_Data/NASBench101'  # Database Path

# %%
benchmark_data = p.load(open(DATABASE_PATH + f'/data.p', 'rb'))
opt_pareto_front = p.load(open(DATABASE_PATH + '/[POF_TestAcc_Params]_[NAS101].p', 'rb'))
min_params, max_params = 227274, 49979274

opt_pareto_front[:, 1] = np.round((opt_pareto_front[:, 1] - min_params) / (max_params - min_params), 4)
opt_pareto_front = np.round(opt_pareto_front, 6)

reference_point = [0.6887 + 1e-4, 49979274.0 + 1e-4]
HV_computing = HV(reference_point)
IGD_computing = IGD(opt_pareto_front)

# %%
summarize_results()
# Out:
# Algorithm: synflow
# Algorithm: jacov
# Algorithm: snip
# Algorithm: grad_norm
# Algorithm: grasp
# Algorithm: fisher
# Algorithm: E-TF-MOENAS
# Algorithm: E-TF-MOENAS-C

# %%
processing_results()
# Out:
# Algorithm: val_error
# Algorithm: moead-val_error
# Algorithm: synflow
# Algorithm: jacov
# Algorithm: snip
# Algorithm: grad_norm
# Algorithm: grasp
# Algorithm: fisher
# Algorithm: ENAS_TFI
# Algorithm: MOENAS_PSI
# Algorithm: MOENAS_TF_PSI
# Algorithm: E-TF-MOENAS
# Algorithm: E-TF-MOENAS-C

# %% [markdown]
# ### IGD (n_eval)

# %%
metric = 'IGD'
fig, ax = plt.subplots()
visualize_xaxis_nEvals()

# %% [markdown]
# ### HV (n_eval)

# %%
metric = 'HV'
fig, ax = plt.subplots()
visualize_xaxis_nEvals()

# %% [markdown]
# ### IGD (hours)

# %%
metric = 'IGD'
fig, ax = plt.subplots()
visualize_xaxis_hours()

# %% [markdown]
# ### HV (hours)

# %%
metric = 'HV'
fig, ax = plt.subplots()
visualize_xaxis_hours()

# %% [markdown]
# ## T-Tests

# %%
run_t_test()
# Out:
# Dataset: CIFAR-10
# val_error
# IGD: 0.0427 (0.0071)
# HV: 0.8984 (0.0024)
# Running Time (avg): 349760
# Best (mean & std): 93.44 (0.19)
# ----------------------------------------------------------------------------------------------------
# moead-val_error
# IGD: 0.0417 (0.0057)
# HV: 0.8948 (0.0026)
# Best (mean & std): 93.25 (0.22)
# ----------------------------------------------------------------------------------------------------
# synflow
# IGD: 0.0479 (0.0075)
# HV: 0.871 (0.0092)
# Running Time (avg): 1130
# Best (mean & std): 91.73 (0.81)
# ----------------------------------------------------------------------------------------------------
# jacov
# IGD: 0.0722 (0.0144)
# HV: 0.8354 (0.0242)
# Running Time (avg): 1992
# Best (mean & std): 89.09 (1.82)
# ----------------------------------------------------------------------------------------------------
# snip
# IGD: 0.0945 (0.0084)
# HV: 0.7632 (0.0124)
# Running Time (avg): 2001
# Best (mean & std): 84.04 (0.88)
# ----------------------------------------------------------------------------------------------------
# grad_norm
# IGD: 0.0974 (0.0072)
# HV: 0.7695 (0.0109)
# Running Time (avg): 2064
# Best (mean & std): 84.51 (0.78)
# ----------------------------------------------------------------------------------------------------
# grasp
# IGD: 0.0906 (0.0151)
# HV: 0.8064 (0.0261)
# Running Time (avg): 8416
# Best (mean & std): 87.1 (1.98)
# ----------------------------------------------------------------------------------------------------
# fisher
# IGD: 0.0868 (0.0049)
# HV: 0.8042 (0.0138)
# Running Time (avg): 263
# Best (mean & std): 86.95 (1.0)
# ----------------------------------------------------------------------------------------------------
# ENAS_TFI
# IGD: 0.0384 (0.0067)
# HV: 0.9001 (0.0021)
# Running Time (avg): 366664
# Best (mean & std): 93.55 (0.16)
# ----------------------------------------------------------------------------------------------------
# MOENAS_PSI
# IGD: 0.041 (0.0075)
# HV: 0.8987 (0.0026)
# Running Time (avg): 355304
# Best (mean & std): 93.48 (0.2)
# ----------------------------------------------------------------------------------------------------
# MOENAS_TF_PSI
# IGD: 0.0409 (0.0079)
# HV: 0.8994 (0.0027)
# Running Time (avg): 346471
# Best (mean & std): 93.51 (0.2)
# ----------------------------------------------------------------------------------------------------
# E-TF-MOENAS
# IGD: 0.0188 (0.0052)
# HV: 0.8952 (0.004)
# Running Time (avg): 5709
# Best (mean & std): 93.65 (0.25)
# ----------------------------------------------------------------------------------------------------
# E-TF-MOENAS-C
# IGD: 0.048 (0.0079)
# HV: 0.8736 (0.0074)
# Running Time (avg): 7268
# Best (mean & std): 91.83 (0.51)
# ----------------------------------------------------------------------------------------------------
# ====================
#
# Alpha: 0.0038461538461538464
#
# Metric: IGD
# IGD val_error moead-val_error
# p_value: 0.5375894246261372
#
# IGD val_error synflow
# p_value: 0.008057775304567041
#
# IGD val_error jacov
# p_value: 1.8636296786945987e-14
# Reject | worse large
#
# IGD val_error snip
# p_value: 3.5592568490333508e-34
# Reject | worse large
#
# IGD val_error grad_norm
# p_value: 2.184920314229744e-37
# Reject | worse large
#
# IGD val_error grasp
# p_value: 7.64611256634903e-23
# Reject | worse large
#
# IGD val_error fisher
# p_value: 5.166065514707901e-36
# Reject | worse large
#
# IGD val_error ENAS_TFI
# p_value: 0.03513894275577397
#
# IGD val_error MOENAS_PSI
# p_value: 0.3615876225463772
#
# IGD val_error MOENAS_TF_PSI
# p_value: 0.3866458316608806
#
# IGD val_error E-TF-MOENAS
# p_value: 1.076078726934552e-21
# Reject | better large
#
# IGD val_error E-TF-MOENAS-C
# p_value: 0.009337842960532286
#
# IGD moead-val_error synflow
# p_value: 0.0006143770837316526
# Reject | worse large
#
# IGD moead-val_error jacov
# p_value: 1.1352026926954986e-15
# Reject | worse large
#
# IGD moead-val_error snip
# p_value: 1.149036070156785e-36
# Reject | worse large
#
# IGD moead-val_error grad_norm
# p_value: 2.766444385891319e-40
# Reject | worse large
#
# IGD moead-val_error grasp
# p_value: 5.027369791131193e-24
# Reject | worse large
#
# IGD moead-val_error fisher
# p_value: 4.6525619594796225e-40
# Reject | worse large
#
# IGD moead-val_error ENAS_TFI
# p_value: 0.06603682444235563
#
# IGD moead-val_error MOENAS_PSI
# p_value: 0.6845504517223595
#
# IGD moead-val_error MOENAS_TF_PSI
# p_value: 0.663108459710591
#
# IGD moead-val_error E-TF-MOENAS
# p_value: 1.3458250752355496e-23
# Reject | better large
#
# IGD moead-val_error E-TF-MOENAS-C
# p_value: 0.0008409082224916984
# Reject | worse large
#
# IGD synflow jacov
# p_value: 2.362286208308553e-11
# Reject | worse large
#
# IGD synflow snip
# p_value: 3.5939551465979985e-31
# Reject | worse large
#
# IGD synflow grad_norm
# p_value: 2.260744405865352e-34
# Reject | worse large
#
# IGD synflow grasp
# p_value: 2.6573282360238307e-20
# Reject | worse large
#
# IGD synflow fisher
# p_value: 3.3211348146620207e-32
# Reject | worse large
#
# IGD synflow ENAS_TFI
# p_value: 2.8988361349132095e-05
# Reject | better large
#
# IGD synflow MOENAS_PSI
# p_value: 0.0006848383899317111
# Reject | better large
#
# IGD synflow MOENAS_TF_PSI
# p_value: 0.0024078709969586306
# Reject | better large
#
# IGD synflow E-TF-MOENAS
# p_value: 3.7218313636014747e-25
# Reject | better large
#
# IGD synflow E-TF-MOENAS-C
# p_value: 0.9793176402009742
#
# IGD jacov snip
# p_value: 6.219218686989833e-10
# Reject | worse large
#
# IGD jacov grad_norm
# p_value: 5.041690700663646e-12
# Reject | worse large
#
# IGD jacov grasp
# p_value: 1.0197183581616857e-05
# Reject | worse large
#
# IGD jacov fisher
# p_value: 1.9670470218807387e-06
# Reject | worse large
#
# IGD jacov ENAS_TFI
# p_value: 2.651234890959616e-13
# Reject | better large
#
# IGD jacov MOENAS_PSI
# p_value: 2.877560547867482e-15
# Reject | better large
#
# IGD jacov MOENAS_TF_PSI
# p_value: 6.678140370192774e-12
# Reject | better large
#
# IGD jacov E-TF-MOENAS
# p_value: 3.6063456536853834e-27
# Reject | better large
#
# IGD jacov E-TF-MOENAS-C
# p_value: 3.770552678982882e-11
# Reject | better large
#
# IGD snip grad_norm
# p_value: 0.1578555170211475
#
# IGD snip grasp
# p_value: 0.21418174675412505
#
# IGD snip fisher
# p_value: 5.1842099387281814e-05
# Reject | better large
#
# IGD snip ENAS_TFI
# p_value: 4.4432003860095426e-30
# Reject | better large
#
# IGD snip MOENAS_PSI
# p_value: 1.617997127076118e-34
# Reject | better large
#
# IGD snip MOENAS_TF_PSI
# p_value: 4.622473300055616e-28
# Reject | better large
#
# IGD snip E-TF-MOENAS
# p_value: 3.3212622279048884e-46
# Reject | better large
#
# IGD snip E-TF-MOENAS-C
# p_value: 1.5251166278776812e-30
# Reject | better large
#
# IGD grad_norm grasp
# p_value: 0.029074898090053473
#
# IGD grad_norm fisher
# p_value: 1.012641527096598e-08
# Reject | better large
#
# IGD grad_norm ENAS_TFI
# p_value: 4.6019425284196146e-33
# Reject | better large
#
# IGD grad_norm MOENAS_PSI
# p_value: 1.2826387446400117e-37
# Reject | better large
#
# IGD grad_norm MOENAS_TF_PSI
# p_value: 7.96488214701497e-31
# Reject | better large
#
# IGD grad_norm E-TF-MOENAS
# p_value: 1.1382256725750348e-49
# Reject | better large
#
# IGD grad_norm E-TF-MOENAS-C
# p_value: 1.2391888744192264e-33
# Reject | better large
#
# IGD grasp fisher
# p_value: 0.20139870868119206
#
# IGD grasp ENAS_TFI
# p_value: 1.3380411393115396e-19
# Reject | better large
#
# IGD grasp MOENAS_PSI
# p_value: 2.010310111094772e-23
# Reject | better large
#
# IGD grasp MOENAS_TF_PSI
# p_value: 2.281672345713205e-18
# Reject | better large
#
# IGD grasp E-TF-MOENAS
# p_value: 5.7573473523328924e-33
# Reject | better large
#
# IGD grasp E-TF-MOENAS-C
# p_value: 4.7678344004844947e-20
# Reject | better large
#
# IGD fisher ENAS_TFI
# p_value: 2.8235466333371207e-33
# Reject | better large
#
# IGD fisher MOENAS_PSI
# p_value: 3.13774088666705e-36
# Reject | better large
#
# IGD fisher MOENAS_TF_PSI
# p_value: 3.326140876210548e-30
# Reject | better large
#
# IGD fisher E-TF-MOENAS
# p_value: 1.6356190897780388e-51
# Reject | better large
#
# IGD fisher E-TF-MOENAS-C
# p_value: 3.0921235547908184e-31
# Reject | better large
#
# IGD ENAS_TFI MOENAS_PSI
# p_value: 0.21112358088119268
#
# IGD ENAS_TFI MOENAS_TF_PSI
# p_value: 0.29195723052610373
#
# IGD ENAS_TFI E-TF-MOENAS
# p_value: 9.103417449845016e-16
# Reject | better large
#
# IGD ENAS_TFI E-TF-MOENAS-C
# p_value: 4.693262115937671e-05
# Reject | worse large
#
# IGD MOENAS_PSI MOENAS_TF_PSI
# p_value: 0.9484702236436633
#
# IGD MOENAS_PSI E-TF-MOENAS
# p_value: 1.2858283197368953e-19
# Reject | better large
#
# IGD MOENAS_PSI E-TF-MOENAS-C
# p_value: 0.0008696977475844824
# Reject | worse large
#
# IGD MOENAS_TF_PSI E-TF-MOENAS
# p_value: 3.550651824954315e-16
# Reject | better large
#
# IGD MOENAS_TF_PSI E-TF-MOENAS-C
# p_value: 0.003030100503960625
# Reject | worse large
#
# IGD E-TF-MOENAS E-TF-MOENAS-C
# p_value: 2.311945237425106e-24
# Reject | worse large
#
# ====================================================================================================
#
# Metric: HV
# HV val_error moead-val_error
# p_value: 7.388344264213504e-07
# Reject | worse large
#
# HV val_error synflow
# p_value: 5.977956143126291e-23
# Reject | worse large
#
# HV val_error jacov
# p_value: 7.431974489430486e-21
# Reject | worse large
#
# HV val_error snip
# p_value: 1.323531809806956e-54
# Reject | worse large
#
# HV val_error grad_norm
# p_value: 1.5396765408316155e-56
# Reject | worse large
#
# HV val_error grasp
# p_value: 2.454839171740976e-27
# Reject | worse large
#
# HV val_error fisher
# p_value: 5.661246639259084e-43
# Reject | worse large
#
# HV val_error ENAS_TFI
# p_value: 0.010870761255916525
#
# HV val_error MOENAS_PSI
# p_value: 0.5901694443780989
#
# HV val_error MOENAS_TF_PSI
# p_value: 0.15992434837850614
#
# HV val_error E-TF-MOENAS
# p_value: 0.0003762476164337686
# Reject | worse large
#
# HV val_error E-TF-MOENAS-C
# p_value: 3.084164943744393e-25
# Reject | worse large
#
# HV moead-val_error synflow
# p_value: 5.565333915524382e-20
# Reject | worse large
#
# HV moead-val_error jacov
# p_value: 1.125495305366303e-19
# Reject | worse large
#
# HV moead-val_error snip
# p_value: 7.717602099959767e-54
# Reject | worse large
#
# HV moead-val_error grad_norm
# p_value: 1.0251622753605498e-55
# Reject | worse large
#
# HV moead-val_error grasp
# p_value: 1.963100844515513e-26
# Reject | worse large
#
# HV moead-val_error fisher
# p_value: 6.04176920959843e-42
# Reject | worse large
#
# HV moead-val_error ENAS_TFI
# p_value: 5.543212346516289e-10
# Reject | better large
#
# HV moead-val_error MOENAS_PSI
# p_value: 2.448017539654811e-07
# Reject | better large
#
# HV moead-val_error MOENAS_TF_PSI
# p_value: 1.7753743956067897e-07
# Reject | better large
#
# HV moead-val_error E-TF-MOENAS
# p_value: 0.6691853375857885
#
# HV moead-val_error E-TF-MOENAS-C
# p_value: 9.438983059523515e-22
# Reject | worse large
#
# HV synflow jacov
# p_value: 3.0293836922358503e-10
# Reject | worse large
#
# HV synflow snip
# p_value: 9.515355233180578e-44
# Reject | worse large
#
# HV synflow grad_norm
# p_value: 3.1991820714338713e-44
# Reject | worse large
#
# HV synflow grasp
# p_value: 8.959440167408237e-19
# Reject | worse large
#
# HV synflow fisher
# p_value: 1.674027266311972e-30
# Reject | worse large
#
# HV synflow ENAS_TFI
# p_value: 7.508737754690922e-19
# Reject | better large
#
# HV synflow MOENAS_PSI
# p_value: 4.323861327683227e-23
# Reject | better large
#
# HV synflow MOENAS_TF_PSI
# p_value: 3.07592652613917e-18
# Reject | better large
#
# HV synflow E-TF-MOENAS
# p_value: 2.329194622422441e-19
# Reject | better large
#
# HV synflow E-TF-MOENAS-C
# p_value: 0.22753296447391982
#
# HV jacov snip
# p_value: 2.5697494959955687e-21
# Reject | worse large
#
# HV jacov grad_norm
# p_value: 5.542181856929132e-20
# Reject | worse large
#
# HV jacov grasp
# p_value: 3.666328035195193e-05
# Reject | worse large
#
# HV jacov fisher
# p_value: 7.009036507212991e-08
# Reject | worse large
#
# HV jacov ENAS_TFI
# p_value: 2.424023309805876e-16
# Reject | better large
#
# HV jacov MOENAS_PSI
# p_value: 5.992797667153755e-21
# Reject | better large
#
# HV jacov MOENAS_TF_PSI
# p_value: 3.8708032193254924e-16
# Reject | better large
#
# HV jacov E-TF-MOENAS
# p_value: 1.1986936688973712e-19
# Reject | better large
#
# HV jacov E-TF-MOENAS-C
# p_value: 1.587869597432293e-11
# Reject | better large
#
# HV snip grad_norm
# p_value: 0.04309951471272427
#
# HV snip grasp
# p_value: 2.3900992364903312e-11
# Reject | better large
#
# HV snip fisher
# p_value: 1.0240580630872131e-17
# Reject | better large
#
# HV snip ENAS_TFI
# p_value: 6.162122130736441e-44
# Reject | better large
#
# HV snip MOENAS_PSI
# p_value: 1.3931935660150808e-54
# Reject | better large
#
# HV snip MOENAS_TF_PSI
# p_value: 1.080286082558891e-43
# Reject | better large
#
# HV snip E-TF-MOENAS
# p_value: 3.2999140690212336e-53
# Reject | better large
#
# HV snip E-TF-MOENAS-C
# p_value: 4.3345427569305874e-46
# Reject | better large
#
# HV grad_norm grasp
# p_value: 1.388945244311174e-09
# Reject | better large
#
# HV grad_norm fisher
# p_value: 1.0648786793918913e-15
# Reject | better large
#
# HV grad_norm ENAS_TFI
# p_value: 1.305169552645491e-45
# Reject | better large
#
# HV grad_norm MOENAS_PSI
# p_value: 1.703024757530461e-56
# Reject | better large
#
# HV grad_norm MOENAS_TF_PSI
# p_value: 2.5328847979043547e-45
# Reject | better large
#
# HV grad_norm E-TF-MOENAS
# p_value: 6.726052217780218e-55
# Reject | better large
#
# HV grad_norm E-TF-MOENAS-C
# p_value: 6.322684763131459e-47
# Reject | better large
#
# HV grasp fisher
# p_value: 0.6767121308908066
#
# HV grasp ENAS_TFI
# p_value: 1.9772252006493506e-21
# Reject | better large
#
# HV grasp MOENAS_PSI
# p_value: 2.1007886618708535e-27
# Reject | better large
#
# HV grasp MOENAS_TF_PSI
# p_value: 2.880826029462158e-21
# Reject | better large
#
# HV grasp E-TF-MOENAS
# p_value: 2.2171742778685733e-26
# Reject | better large
#
# HV grasp E-TF-MOENAS-C
# p_value: 5.933320241494544e-20
# Reject | better large
#
# HV fisher ENAS_TFI
# p_value: 2.2586496830768286e-34
# Reject | better large
#
# HV fisher MOENAS_PSI
# p_value: 5.383005341780888e-43
# Reject | better large
#
# HV fisher MOENAS_TF_PSI
# p_value: 4.09467845170747e-34
# Reject | better large
#
# HV fisher E-TF-MOENAS
# p_value: 1.7545549116764814e-41
# Reject | better large
#
# HV fisher E-TF-MOENAS-C
# p_value: 8.199950730163953e-33
# Reject | better large
#
# HV ENAS_TFI MOENAS_PSI
# p_value: 0.052428319552630116
#
# HV ENAS_TFI MOENAS_TF_PSI
# p_value: 0.36539604580184504
#
# HV ENAS_TFI E-TF-MOENAS
# p_value: 4.945244258780191e-06
# Reject | worse large
#
# HV ENAS_TFI E-TF-MOENAS-C
# p_value: 5.2843327751630166e-21
# Reject | worse large
#
# HV MOENAS_PSI MOENAS_TF_PSI
# p_value: 0.3733811094195967
#
# HV MOENAS_PSI E-TF-MOENAS
# p_value: 0.00013509193139744165
# Reject | worse large
#
# HV MOENAS_PSI E-TF-MOENAS-C
# p_value: 2.4079344608600084e-25
# Reject | worse large
#
# HV MOENAS_TF_PSI E-TF-MOENAS
# p_value: 0.00011829640371842063
# Reject | worse large
#
# HV MOENAS_TF_PSI E-TF-MOENAS-C
# p_value: 3.268554541495981e-20
# Reject | worse large
#
# HV E-TF-MOENAS E-TF-MOENAS-C
# p_value: 1.0818017024206442e-20
# Reject | worse large
#
# ====================================================================================================
